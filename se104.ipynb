# %%
from selenium.webdriver import Chrome
from bs4 import BeautifulSoup
import time

driver = Chrome('./chromedriver.exe')

url = 'https://www.104.com.tw/jobs/main/'

driver.get(url)

driver.find_element_by_xpath('/html/body/article[1]/div/div/div[4]/div/button').click()
time.sleep(1)

# driver.find_element_by_xpath('//*[@id="js-job-content"]/div[5]/button[2]').click()
# time.sleep(5)

# # 將網頁畫面往下滾動至離頂部 5000 高度的位子
# driver.execute_script('var s = document.documentElement.scrollTop=5000')
# time.sleep(5)

# # 將網頁畫面滾到最上方
# driver.execute_script('var s = document.documentElement.scrollTop=0')
# time.sleep(5)
for i in range(0,10):
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
    time.sleep(1)

# 取得目前的 html 字串
html = driver.execute_script("return document.getElementsByTagName('html')[0].outerHTML")
# print(html)


p = 1
while p != 0 :
    driver.find_element_by_class_name('js-loading-next-page',)[-1].click()
    print('載入第' + str(p) + '頁')
    p += 1
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-1-c702f2bdadf3> in <module>
#      33 p = 1
#      34 while p != 0 :
# ---> 35     driver.find_element_by_class_name('js-loading-next-page',)[-1].click()
#      36     print('載入第' + str(p) + '頁')
#      37     p += 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".js-loading-next-page"}
#   (Session info: chrome=89.0.4389.90)

# %%
soup = BeautifulSoup(html,'html.parser')
articleList = soup.select('article')
    # print(article)

all_job_datas=[]
    
for article in articleList: 
    try:
        Opening = article.select('a[class="js-job-link"]')[0].text
        joburl = 'https:' + article.select('a[class="js-job-link"]')[0]['href']
        CompanyName = article.select('ul[class="b-list-inline b-clearfix"] a')[0].text.lstrip()
        jobContent = article.select('p[class="job-list-item__info b-clearfix b-content"]')[0].text
        
        job_data={
                    
                '職缺':Opening,
                '公司名稱':CompanyName,
                '網址':joburl,
                '工作內容':jobContent
                    
        }
            
        all_job_datas.append(job_data)
            
            
    except IndexError as n:
        print(n)
# Out:
# list index out of range
# list index out of range
# list index out of range

# %%
import pandas as pd
df = pd.DataFrame(all_job_datas)
df
# Out:
#                                                     職缺  \
# 0                              軟體工程師 Software Engineer
# 1                                    光通訊模組機構工程師@平鎮_108
# 2    【保障5萬9個月】彈性工作8小時，360小時培訓，挑戰百萬年薪*(科技輔助效率高，挑戰百萬年...
# 3                【一蘭拉麵-全時段/大夜熱烈募集中】正職輪休制-內外場服務人員~起薪31K
# 4                                                  營養師
# ..                                                 ...
# 244                                  早班門市人員(正職)月薪3萬不是夢
# 245                                      【桃園】海空運報關採購人員
# 246                                               廚房夥伴
# 247                            【Closet衣櫥餐酒館】外場正職人員，調酒師
